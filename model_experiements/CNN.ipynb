# %% [markdown]
# # From Detection to Credibility: A Machine Learning Framework for Assessing News Source Reliability

# %%
# !pip3 install -r ../requirements.txt

# %%
# Import necessary libraries

# Data manipulation
import pandas as pd
import numpy as np

# Statistical functions
from scipy.stats import zscore

# For concurrency (running functions in parallel)
from concurrent.futures import ThreadPoolExecutor

# For caching (to speed up repeated function calls)
from functools import lru_cache

# For progress tracking
from tqdm import tqdm


# Text Preprocessing and NLP
import nltk
# Stopwords (common words to ignore) from NLTK
from nltk.corpus import stopwords
# Tokenizing sentences/words
from nltk.tokenize import word_tokenize
# Part-of-speech tagging
from nltk import pos_tag
# Lemmatization (converting words to their base form)
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # Data Preparation (Loading CSV)
#
# Load the processed_data `csv` file into pandas DataFrames
# - `processed_data.csv` is loaded into `data` DataFrame (stemming has been performed to reduce processing time.)

# %%
data = pd.read_csv('../processed_data.csv')

# %%
data.info()
print("Dataframe Shape:", data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63860 entries, 0 to 63859
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   label                   63860 non-null  int64
#  1   full_content            63860 non-null  object
#  2   processed_full_content  63860 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.5+ MB
# Dataframe Shape: (63860, 3)

# %%
data.head()
# Out:
#    label                                       full_content  \
# 0      1  No comment is expected from Barack Obama Membe...
# 1      1     Did they post their votes for Hillary already?
# 2      1  Now, most of the demonstrators gathered last n...
# 3      0  A dozen politically active pastors came here f...
# 4      1  The RS-28 Sarmat missile, dubbed Satan 2, will...
#
#                               processed_full_content
# 0  no comment expect barack obama member fyf911 f...
# 1                          post vote hillari alreadi
# 2  demonstr gather last night exercis constitut p...
# 3  dozen polit activ pastor came privat dinner fr...
# 4  rs-28 sarmat missil dub satan 2 replac ss-18 f...

# %%
data.isnull().sum()
# Out:
# label                     0
# full_content              0
# processed_full_content    0
# dtype: int64

# %%
data['label'].value_counts()
# Out:
# label
# 0    34779
# 1    29081
# Name: count, dtype: int64

# %%
# Ensure required NLTK data is downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('all')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/dariusng2103/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/dariusng2103/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/dariusng2103/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/dariusng2103/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /home/dariusng2103/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %% [markdown]
# ### Basic Convolutional Neural Network (Tokenizer + Embedding Layer) + 5 Fold Cross-Validation + L2 Regularization

# %%
import tensorflow as tf
import numpy as np
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# Tokenization and Padding Parameters
max_words = 10000  # Max vocabulary size
max_sequence_length = 300  # Max length of sequences

# Tokenize and Pad Sequences
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(data['processed_full_content'])
sequences = tokenizer.texts_to_sequences(data['processed_full_content'])
X = pad_sequences(sequences, maxlen=max_sequence_length)
y = data['label'].values  # Target labels

# Define the CNN Model with L2 Regularization
def create_basic_cnn():
    model = Sequential()
    model.add(Embedding(input_dim=max_words, output_dim=128, input_length=max_sequence_length))
    model.add(Conv1D(filters=128, kernel_size=5, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(GlobalMaxPooling1D())
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.5))  # Add dropout for regularization
    model.add(Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01)))  # Binary classification

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# 5-Fold Cross-Validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold = 1
all_fold_metrics = {'accuracy': [], 'precision': [], 'recall': [], 'f1': []}

for train_index, val_index in kf.split(X, y):
    print(f"\nTraining fold {fold}...")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    model = create_basic_cnn()
    history = model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_val, y_val), verbose=1)
    
    # Predict and evaluate
    y_pred = (model.predict(X_val) > 0.5).astype(int)
    accuracy = accuracy_score(y_val, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_val, y_pred, average='binary')
    
    # Store metrics for this fold
    all_fold_metrics['accuracy'].append(accuracy)
    all_fold_metrics['precision'].append(precision)
    all_fold_metrics['recall'].append(recall)
    all_fold_metrics['f1'].append(f1)
    
    print(f"Fold {fold} - Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}")
    fold += 1

# Calculate and print average metrics across all folds
avg_accuracy = np.mean(all_fold_metrics['accuracy'])
avg_precision = np.mean(all_fold_metrics['precision'])
avg_recall = np.mean(all_fold_metrics['recall'])
avg_f1 = np.mean(all_fold_metrics['f1'])

print("\nAverage Evaluation Metrics across 5 folds:")
print(f"Average Accuracy: {avg_accuracy:.4f}")
print(f"Average Precision: {avg_precision:.4f}")
print(f"Average Recall: {avg_recall:.4f}")
print(f"Average F1 Score: {avg_f1:.4f}")
# Out:
# 2024-11-06 14:03:17.371651: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-06 14:03:17.486219: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1730872997.530685     747 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1730872997.543159     747 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-06 14:03:17.653495: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training fold 1...
# /home/dariusng2103/projects/dm_project/tf217/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# I0000 00:00:1730873018.871822     747 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9557 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730873019.811247    4171 service.cc:148] XLA service 0x7f1280014fd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730873019.811470    4171 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2024-11-06 14:03:39.842899: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1730873019.945921    4171 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  94/799 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5845 - loss: 1.8652
# I0000 00:00:1730873020.949878    4171 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8193 - loss: 0.7628 - val_accuracy: 0.9577 - val_loss: 0.2331
# Epoch 2/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9584 - loss: 0.2266 - val_accuracy: 0.9643 - val_loss: 0.2051
# Epoch 3/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9704 - loss: 0.1922 - val_accuracy: 0.9665 - val_loss: 0.1916
# Epoch 4/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9776 - loss: 0.1711 - val_accuracy: 0.9669 - val_loss: 0.1842
# Epoch 5/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9831 - loss: 0.1562 - val_accuracy: 0.9663 - val_loss: 0.1827
# Epoch 6/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9855 - loss: 0.1450 - val_accuracy: 0.9669 - val_loss: 0.1759
# Epoch 7/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9881 - loss: 0.1360 - val_accuracy: 0.9660 - val_loss: 0.1730
# Epoch 8/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9891 - loss: 0.1290 - val_accuracy: 0.9662 - val_loss: 0.1707
# Epoch 9/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9913 - loss: 0.1219 - val_accuracy: 0.9663 - val_loss: 0.1693
# Epoch 10/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9922 - loss: 0.1177 - val_accuracy: 0.9672 - val_loss: 0.1640
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# Fold 1 - Accuracy: 0.9672, Precision: 0.9707, Recall: 0.9569, F1 Score: 0.9637
#
# Training fold 2...
# Epoch 1/10
# /home/dariusng2103/projects/dm_project/tf217/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8315 - loss: 0.7543 - val_accuracy: 0.9594 - val_loss: 0.2321
# Epoch 2/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9610 - loss: 0.2247 - val_accuracy: 0.9636 - val_loss: 0.2072
# Epoch 3/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9716 - loss: 0.1899 - val_accuracy: 0.9667 - val_loss: 0.1928
# Epoch 4/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9789 - loss: 0.1699 - val_accuracy: 0.9678 - val_loss: 0.1847
# Epoch 5/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9830 - loss: 0.1550 - val_accuracy: 0.9676 - val_loss: 0.1807
# Epoch 6/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9869 - loss: 0.1440 - val_accuracy: 0.9675 - val_loss: 0.1765
# Epoch 7/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9890 - loss: 0.1356 - val_accuracy: 0.9682 - val_loss: 0.1740
# Epoch 8/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9909 - loss: 0.1283 - val_accuracy: 0.9691 - val_loss: 0.1704
# Epoch 9/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9921 - loss: 0.1224 - val_accuracy: 0.9684 - val_loss: 0.1679
# Epoch 10/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9931 - loss: 0.1171 - val_accuracy: 0.9677 - val_loss: 0.1666
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# Fold 2 - Accuracy: 0.9677, Precision: 0.9641, Recall: 0.9651, F1 Score: 0.9646
#
# Training fold 3...
# Epoch 1/10
# /home/dariusng2103/projects/dm_project/tf217/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8305 - loss: 0.7702 - val_accuracy: 0.9579 - val_loss: 0.2282
# Epoch 2/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9585 - loss: 0.2270 - val_accuracy: 0.9640 - val_loss: 0.2019
# Epoch 3/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9708 - loss: 0.1910 - val_accuracy: 0.9663 - val_loss: 0.1882
# Epoch 4/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9784 - loss: 0.1707 - val_accuracy: 0.9675 - val_loss: 0.1810
# Epoch 5/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9828 - loss: 0.1561 - val_accuracy: 0.9674 - val_loss: 0.1759
# Epoch 6/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9854 - loss: 0.1453 - val_accuracy: 0.9681 - val_loss: 0.1711
# Epoch 7/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9890 - loss: 0.1353 - val_accuracy: 0.9676 - val_loss: 0.1700
# Epoch 8/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9902 - loss: 0.1287 - val_accuracy: 0.9681 - val_loss: 0.1651
# Epoch 9/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9915 - loss: 0.1228 - val_accuracy: 0.9688 - val_loss: 0.1632
# Epoch 10/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9927 - loss: 0.1171 - val_accuracy: 0.9672 - val_loss: 0.1660
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step
# Fold 3 - Accuracy: 0.9671, Precision: 0.9509, Recall: 0.9783, F1 Score: 0.9644
#
# Training fold 4...
# Epoch 1/10
# /home/dariusng2103/projects/dm_project/tf217/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8281 - loss: 0.7717 - val_accuracy: 0.9543 - val_loss: 0.2351
# Epoch 2/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9601 - loss: 0.2263 - val_accuracy: 0.9574 - val_loss: 0.2113
# Epoch 3/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9714 - loss: 0.1913 - val_accuracy: 0.9627 - val_loss: 0.1964
# Epoch 4/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9798 - loss: 0.1698 - val_accuracy: 0.9644 - val_loss: 0.1901
# Epoch 5/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9831 - loss: 0.1551 - val_accuracy: 0.9635 - val_loss: 0.1837
# Epoch 6/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9869 - loss: 0.1433 - val_accuracy: 0.9648 - val_loss: 0.1788
# Epoch 7/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9892 - loss: 0.1351 - val_accuracy: 0.9655 - val_loss: 0.1743
# Epoch 8/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9916 - loss: 0.1270 - val_accuracy: 0.9663 - val_loss: 0.1708
# Epoch 9/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9924 - loss: 0.1214 - val_accuracy: 0.9658 - val_loss: 0.1705
# Epoch 10/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9923 - loss: 0.1161 - val_accuracy: 0.9660 - val_loss: 0.1674
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# Fold 4 - Accuracy: 0.9660, Precision: 0.9569, Recall: 0.9691, F1 Score: 0.9629
#
# Training fold 5...
# /home/dariusng2103/projects/dm_project/tf217/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8437 - loss: 0.7758 - val_accuracy: 0.9565 - val_loss: 0.2355
# Epoch 2/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9599 - loss: 0.2276 - val_accuracy: 0.9644 - val_loss: 0.2051
# Epoch 3/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9714 - loss: 0.1906 - val_accuracy: 0.9646 - val_loss: 0.1926
# Epoch 4/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9795 - loss: 0.1691 - val_accuracy: 0.9677 - val_loss: 0.1856
# Epoch 5/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9830 - loss: 0.1554 - val_accuracy: 0.9691 - val_loss: 0.1793
# Epoch 6/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9864 - loss: 0.1443 - val_accuracy: 0.9679 - val_loss: 0.1767
# Epoch 7/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9888 - loss: 0.1355 - val_accuracy: 0.9675 - val_loss: 0.1737
# Epoch 8/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9909 - loss: 0.1281 - val_accuracy: 0.9693 - val_loss: 0.1688
# Epoch 9/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9918 - loss: 0.1224 - val_accuracy: 0.9684 - val_loss: 0.1668
# Epoch 10/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9934 - loss: 0.1168 - val_accuracy: 0.9678 - val_loss: 0.1652
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step
# Fold 5 - Accuracy: 0.9678, Precision: 0.9742, Recall: 0.9546, F1 Score: 0.9643
#
# Average Evaluation Metrics across 5 folds:
# Average Accuracy: 0.9672
# Average Precision: 0.9634
# Average Recall: 0.9648
# Average F1 Score: 0.9640

# %% [markdown]
# ### Convolutional Neural Network + TF-IDF Vectorizer
#
# Using TF-IDF vectorizer along with CNN led to a drastic fall in performance. Below are some reasons why we should not use TF-IDF vectorizer along with a CNN or other neural networks.

# %% [markdown]
# #### Lack of Spatial Structure:
#
# TF-IDF vectors are sparse and non-sequential representations where each position in the vector represents a word, not a spatial pattern.
# CNNs are designed to detect patterns in sequential or spatially structured data (e.g., images or sentences), so they might struggle to find meaningful patterns in TF-IDF vectors.
#
# #### High-Dimensional Sparse Data:
#
# TF-IDF vectors, especially with a high max_features value (like 10,000), result in a high-dimensional but sparse input.
# CNNs are generally not well-suited for such high-dimensional sparse data; they perform better with dense embeddings where words have contextually meaningful dimensions.
#
# #### Mismatch Between Input Type and CNN Architecture:
#
# CNNs are typically effective when applied to word embeddings (like GloVe or Word2Vec) because embeddings maintain semantic relationships and neighborhood structures.
# TF-IDF, however, does not capture word order or semantic relationships, which means the convolution operation might not yield meaningful feature maps.

# %%
import tensorflow as tf
import numpy as np
import random

tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, Dense, Dropout, Reshape, Input
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# Step 1: Apply TF-IDF Vectorization
max_features = 10000  # Limit TF-IDF to top 10,000 features
tfidf_vectorizer = TfidfVectorizer(max_features=max_features)
X_tfidf = tfidf_vectorizer.fit_transform(data['processed_full_content']).toarray()

# Convert the labels
y = data['label'].values  # Target labels

# Step 2: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# Step 3: Define the CNN Model for TF-IDF Input
def create_cnn_with_tfidf():
    inputs = Input(shape=(max_features,))
    x = Reshape((max_features, 1))(inputs)  # Reshape TF-IDF output to be compatible with Conv1D

    # Convolutional layer
    x = Conv1D(filters=128, kernel_size=5, activation='relu')(x)
    x = GlobalMaxPooling1D()(x)
    
    # Fully connected layer
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.5)(x)  # Dropout for regularization
    outputs = Dense(1, activation='sigmoid')(x)  # Output layer for binary classification

    # Create model
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Step 4: Train the Model
model = create_cnn_with_tfidf()
history = model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_test, y_test), verbose=1)

# Step 5: Evaluate the Model
y_pred = (model.predict(X_test) > 0.5).astype(int)
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')

print("\nEvaluation Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Epoch 1/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 24s 24ms/step - accuracy: 0.5353 - loss: 0.6893 - val_accuracy: 0.5483 - val_loss: 0.6825
# Epoch 2/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.5550 - loss: 0.6836 - val_accuracy: 0.5729 - val_loss: 0.6786
# Epoch 3/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.5565 - loss: 0.6815 - val_accuracy: 0.5727 - val_loss: 0.6772
# Epoch 4/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5610 - loss: 0.6801 - val_accuracy: 0.5727 - val_loss: 0.6752
# Epoch 5/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5593 - loss: 0.6793 - val_accuracy: 0.5710 - val_loss: 0.6766
# Epoch 6/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.5620 - loss: 0.6795 - val_accuracy: 0.5711 - val_loss: 0.6749
# Epoch 7/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5590 - loss: 0.6791 - val_accuracy: 0.5730 - val_loss: 0.6756
# Epoch 8/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5605 - loss: 0.6782 - val_accuracy: 0.5716 - val_loss: 0.6750
# Epoch 9/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.5611 - loss: 0.6790 - val_accuracy: 0.5679 - val_loss: 0.6757
# Epoch 10/10
# 799/799 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.5598 - loss: 0.6789 - val_accuracy: 0.5718 - val_loss: 0.6747
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# Evaluation Metrics:
# Accuracy: 0.5718
# Precision: 0.5550
# Recall: 0.2614
# F1 Score: 0.3555

# %% [markdown]
# ### Convolutional Neural Networks + Count Vectorization (conversion to sequences) + Stratified 5-Fold CV + L2 Regularization

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from tensorflow.keras.regularizers import l2

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Step 1: Text Vectorization using CountVectorizer
max_features = 10000  # Max vocabulary size for CountVectorizer
vectorizer = CountVectorizer(max_features=max_features)
X_counts = vectorizer.fit_transform(data['processed_full_content'])
word_index = vectorizer.vocabulary_

# Convert CountVectorizer output to sequences
index_to_word = {i: word for word, i in word_index.items()}

def counts_to_sequences(X_counts):
    sequences = []
    for i in range(X_counts.shape[0]):
        indices = X_counts[i].nonzero()[1]
        words = [index_to_word[idx] for idx in indices]
        seq = [word_index[word] + 1 for word in words]  # +1 because 0 is reserved for padding
        sequences.append(seq)
    return sequences

sequences = counts_to_sequences(X_counts)
max_sequence_length = 300  # Adjust to your needs
X = pad_sequences(sequences, maxlen=max_sequence_length)
y = data['label'].values  # Target labels

# Define the Basic CNN Model with L2 Regularization
def create_basic_cnn_with_l2():
    model = Sequential()
    
    # Embedding layer with random initialization
    model.add(Embedding(input_dim=max_features + 1, output_dim=128))
    
    # Convolutional layer with L2 regularization
    model.add(Conv1D(filters=128, kernel_size=5, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(GlobalMaxPooling1D())
    
    # Fully connected layer with L2 regularization
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.5))  # Add dropout for regularization
    
    # Output layer with L2 regularization
    model.add(Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01)))  # Binary classification
    
    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Step 4: Stratified 5-Fold Cross-Validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for train_index, test_index in kf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    model = create_basic_cnn_with_l2()
    model.fit(X_train, y_train, epochs=10, batch_size=64, validation_split=0.2, verbose=1)
    
    # Evaluate the model
    y_pred = (model.predict(X_test) > 0.5).astype(int)
    
    accuracy = accuracy_score(y_test, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
    
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)

# Step 5: Print Cross-Validation Results
print("\nCross-Validation Metrics:")
print(f"Average Accuracy: {np.mean(accuracy_scores):.4f}")
print(f"Average Precision: {np.mean(precision_scores):.4f}")
print(f"Average Recall: {np.mean(recall_scores):.4f}")
print(f"Average F1 Score: {np.mean(f1_scores):.4f}")
# Out:
# Epoch 1/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7685 - loss: 0.8773 - val_accuracy: 0.9291 - val_loss: 0.2726
# Epoch 2/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9301 - loss: 0.2740 - val_accuracy: 0.9330 - val_loss: 0.2610
# Epoch 3/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9425 - loss: 0.2451 - val_accuracy: 0.9389 - val_loss: 0.2481
# Epoch 4/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9531 - loss: 0.2220 - val_accuracy: 0.9424 - val_loss: 0.2419
# Epoch 5/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9605 - loss: 0.2073 - val_accuracy: 0.9360 - val_loss: 0.2567
# Epoch 6/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9662 - loss: 0.1931 - val_accuracy: 0.9419 - val_loss: 0.2467
# Epoch 7/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9734 - loss: 0.1802 - val_accuracy: 0.9399 - val_loss: 0.2534
# Epoch 8/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9773 - loss: 0.1705 - val_accuracy: 0.9445 - val_loss: 0.2412
# Epoch 9/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9794 - loss: 0.1619 - val_accuracy: 0.9475 - val_loss: 0.2339
# Epoch 10/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9828 - loss: 0.1551 - val_accuracy: 0.9471 - val_loss: 0.2353
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# Epoch 1/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7846 - loss: 0.8602 - val_accuracy: 0.9339 - val_loss: 0.2573
# Epoch 2/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9291 - loss: 0.2680 - val_accuracy: 0.9400 - val_loss: 0.2368
# Epoch 3/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9435 - loss: 0.2387 - val_accuracy: 0.9455 - val_loss: 0.2253
# Epoch 4/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9534 - loss: 0.2171 - val_accuracy: 0.9482 - val_loss: 0.2195
# Epoch 5/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9627 - loss: 0.2006 - val_accuracy: 0.9508 - val_loss: 0.2163
# Epoch 6/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9689 - loss: 0.1880 - val_accuracy: 0.9524 - val_loss: 0.2154
# Epoch 7/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9747 - loss: 0.1753 - val_accuracy: 0.9530 - val_loss: 0.2139
# Epoch 8/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9783 - loss: 0.1667 - val_accuracy: 0.9527 - val_loss: 0.2132
# Epoch 9/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9815 - loss: 0.1582 - val_accuracy: 0.9506 - val_loss: 0.2159
# Epoch 10/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9841 - loss: 0.1533 - val_accuracy: 0.9497 - val_loss: 0.2161
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# Epoch 1/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7873 - loss: 0.8809 - val_accuracy: 0.9249 - val_loss: 0.2743
# Epoch 2/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9311 - loss: 0.2674 - val_accuracy: 0.9410 - val_loss: 0.2399
# Epoch 3/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9460 - loss: 0.2361 - val_accuracy: 0.9487 - val_loss: 0.2275
# Epoch 4/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9565 - loss: 0.2157 - val_accuracy: 0.9496 - val_loss: 0.2240
# Epoch 5/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9634 - loss: 0.2003 - val_accuracy: 0.9504 - val_loss: 0.2213
# Epoch 6/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9692 - loss: 0.1861 - val_accuracy: 0.9460 - val_loss: 0.2306
# Epoch 7/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9740 - loss: 0.1776 - val_accuracy: 0.9478 - val_loss: 0.2266
# Epoch 8/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9786 - loss: 0.1664 - val_accuracy: 0.9482 - val_loss: 0.2265
# Epoch 9/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9822 - loss: 0.1578 - val_accuracy: 0.9476 - val_loss: 0.2260
# Epoch 10/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9827 - loss: 0.1535 - val_accuracy: 0.9524 - val_loss: 0.2193
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# Epoch 1/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7982 - loss: 0.8463 - val_accuracy: 0.9334 - val_loss: 0.2572
# Epoch 2/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9337 - loss: 0.2628 - val_accuracy: 0.9414 - val_loss: 0.2371
# Epoch 3/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9434 - loss: 0.2377 - val_accuracy: 0.9428 - val_loss: 0.2311
# Epoch 4/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9522 - loss: 0.2181 - val_accuracy: 0.9500 - val_loss: 0.2214
# Epoch 5/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9611 - loss: 0.2006 - val_accuracy: 0.9509 - val_loss: 0.2207
# Epoch 6/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9686 - loss: 0.1865 - val_accuracy: 0.9524 - val_loss: 0.2184
# Epoch 7/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9732 - loss: 0.1749 - val_accuracy: 0.9514 - val_loss: 0.2207
# Epoch 8/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9786 - loss: 0.1664 - val_accuracy: 0.9524 - val_loss: 0.2173
# Epoch 9/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9812 - loss: 0.1576 - val_accuracy: 0.9530 - val_loss: 0.2146
# Epoch 10/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9835 - loss: 0.1525 - val_accuracy: 0.9517 - val_loss: 0.2160
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# Epoch 1/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7969 - loss: 0.8712 - val_accuracy: 0.9279 - val_loss: 0.2604
# Epoch 2/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9319 - loss: 0.2652 - val_accuracy: 0.9403 - val_loss: 0.2380
# Epoch 3/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9466 - loss: 0.2333 - val_accuracy: 0.9472 - val_loss: 0.2263
# Epoch 4/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9573 - loss: 0.2118 - val_accuracy: 0.9487 - val_loss: 0.2242
# Epoch 5/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9661 - loss: 0.1951 - val_accuracy: 0.9487 - val_loss: 0.2232
# Epoch 6/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9728 - loss: 0.1820 - val_accuracy: 0.9480 - val_loss: 0.2259
# Epoch 7/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9768 - loss: 0.1710 - val_accuracy: 0.9498 - val_loss: 0.2226
# Epoch 8/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9814 - loss: 0.1619 - val_accuracy: 0.9508 - val_loss: 0.2211
# Epoch 9/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9847 - loss: 0.1520 - val_accuracy: 0.9507 - val_loss: 0.2196
# Epoch 10/10
# 639/639 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9867 - loss: 0.1446 - val_accuracy: 0.9508 - val_loss: 0.2183
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
#
# Cross-Validation Metrics:
# Average Accuracy: 0.9474
# Average Precision: 0.9454
# Average Recall: 0.9393
# Average F1 Score: 0.9421

# %% [markdown]
# ### Convolutional Neural Network + Custom-trained Word2Vec Embeddings + 5-Fold Cross Validation + L2 Regularization

# %% [markdown]
# #### Why do we use word embedding over other preprocessing techniques (eg. tf-idf, count vectorizer), for our task of fake news classification?
#
#
# ##### 1. Word embeddings capture the semantic relationships between words in a dense, low-dimensional space.
# Fake news often uses subtle language, and word embeddings like GloVe can capture the semantic context of words, allowing the model to understand relationships between words that simple vectorizers would miss. This helps in detecting nuanced differences in language use between real and fake news.
#
# ##### 2. Word embeddings produce dense, low-dimensional vectors (e.g., 100-300 dimensions) that capture rich word information.
# Pre-trained embeddings are built on large corpora like Wikipedia and news articles, giving our model external knowledge that’s useful for distinguishing between real news and fake news. This boosts the model's ability to generalize on unseen test data from our web scraping.
#
# ##### 3. Efficient Representation of Semantics
# Words in fake news can appear in different contexts, but with similar underlying meanings (e.g., "hoax" and "lie"). GloVe embeddings represent these similar words in close proximity in the vector space, helping the model recognize fake news patterns more effectively than TF-IDF or Count Vectorizer.
#
# ##### 4. Handling Synonyms and Rare Words:
# Fake news often uses alternative phrases or rare terminology. Pre-trained embeddings like GloVe can handle these rare words because they’ve seen a broad variety of language during training, making our model more robust against unusual vocabulary choices in fake news.

# %% [markdown]
# ## Cross Validation
# We use Stratified K-Fold Cross-Validation with n_splits=5 to evaluate the model on different splits of the data.
# For each fold, we store the metrics (accuracy, precision, recall, and F1 score) and then calculate the average metrics across all folds for a robust evaluation.
#
# Cross-validation helps us understand the model’s performance more robustly by testing it on multiple splits of the data. This approach gives a more reliable estimate of model performance and helps reduce the risk of overfitting to any single train-test split.

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from gensim.models import Word2Vec
from tensorflow.keras.regularizers import l2

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Tokenization parameters
max_words = 5000
max_sequence_length = 300

# Tokenize and create sequences
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(data['processed_full_content'])
sequences = tokenizer.texts_to_sequences(data['processed_full_content'])
X = pad_sequences(sequences, maxlen=max_sequence_length)
y = data['label'].values

# Step 2: Train Word2Vec Embeddings
sentences = [text.split() for text in data['processed_full_content']]
embedding_dim = 100
custom_word2vec = Word2Vec(sentences, vector_size=embedding_dim, window=5, min_count=2, workers=4)

# Step 3: Create Embedding Matrix from Custom Word2Vec
vocab_size = len(tokenizer.word_index) + 1
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in tokenizer.word_index.items():
    if i < max_words:
        if word in custom_word2vec.wv:
            embedding_matrix[i] = custom_word2vec.wv[word]
        else:
            embedding_matrix[i] = np.random.normal(size=(embedding_dim,))

# Define CNN Model with Custom Word2Vec Embeddings and L2 Regularization
def create_cnn_with_l2():
    input_layer = Input(shape=(max_sequence_length,))
    embedding_layer = Embedding(input_dim=vocab_size,
                                output_dim=embedding_dim,
                                weights=[embedding_matrix],
                                trainable=True)(input_layer)

    x = Conv1D(filters=64, kernel_size=5, activation='relu', kernel_regularizer=l2(0.01))(embedding_layer)
    x = GlobalMaxPooling1D()(x)
    x = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(0.5)(x)
    output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(x)

    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Implement Stratified 5-Fold Cross-Validation
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
accuracies, precisions, recalls, f1_scores = [], [], [], []

for train_index, test_index in kfold.split(X, y):
    X_train, X_val = X[train_index], X[test_index]
    y_train, y_val = y[train_index], y[test_index]

    # Create and train the CNN model
    model = create_cnn_with_l2()
    model.fit(X_train, y_train, epochs=10, batch_size=256, validation_data=(X_val, y_val), verbose=1)

    # Evaluate model on validation set
    y_pred = (model.predict(X_val) > 0.5).astype(int)
    accuracy = accuracy_score(y_val, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_val, y_pred, average='binary')

    # Collect metrics
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

# Calculate and display average metrics
avg_accuracy = np.mean(accuracies)
avg_precision = np.mean(precisions)
avg_recall = np.mean(recalls)
avg_f1_score = np.mean(f1_scores)

print("\nAggregated Evaluation Metrics:")
print(f"Average Accuracy: {avg_accuracy:.4f}")
print(f"Average Precision: {avg_precision:.4f}")
print(f"Average Recall: {avg_recall:.4f}")
print(f"Average F1 Score: {avg_f1_score:.4f}")
# Out:
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7829 - loss: 1.7065 - val_accuracy: 0.9429 - val_loss: 0.6274
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9409 - loss: 0.5485 - val_accuracy: 0.9536 - val_loss: 0.3495
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9572 - loss: 0.3277 - val_accuracy: 0.9627 - val_loss: 0.2546
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9650 - loss: 0.2447 - val_accuracy: 0.9689 - val_loss: 0.2093
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9701 - loss: 0.2028 - val_accuracy: 0.9693 - val_loss: 0.1872
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9728 - loss: 0.1777 - val_accuracy: 0.9720 - val_loss: 0.1726
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9758 - loss: 0.1660 - val_accuracy: 0.9729 - val_loss: 0.1662
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9774 - loss: 0.1573 - val_accuracy: 0.9713 - val_loss: 0.1607
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9784 - loss: 0.1506 - val_accuracy: 0.9680 - val_loss: 0.1662
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9801 - loss: 0.1458 - val_accuracy: 0.9682 - val_loss: 0.1622
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 928us/step
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8012 - loss: 1.6375 - val_accuracy: 0.9499 - val_loss: 0.5983
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9478 - loss: 0.5223 - val_accuracy: 0.9618 - val_loss: 0.3179
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9623 - loss: 0.3031 - val_accuracy: 0.9663 - val_loss: 0.2372
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9685 - loss: 0.2298 - val_accuracy: 0.9665 - val_loss: 0.2013
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9724 - loss: 0.1931 - val_accuracy: 0.9674 - val_loss: 0.1870
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9749 - loss: 0.1721 - val_accuracy: 0.9676 - val_loss: 0.1756
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9769 - loss: 0.1608 - val_accuracy: 0.9645 - val_loss: 0.1803
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9761 - loss: 0.1562 - val_accuracy: 0.9691 - val_loss: 0.1672
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9788 - loss: 0.1497 - val_accuracy: 0.9717 - val_loss: 0.1595
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9810 - loss: 0.1451 - val_accuracy: 0.9724 - val_loss: 0.1569
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7831 - loss: 1.7301 - val_accuracy: 0.9485 - val_loss: 0.6279
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9464 - loss: 0.5457 - val_accuracy: 0.9619 - val_loss: 0.3380
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9614 - loss: 0.3175 - val_accuracy: 0.9648 - val_loss: 0.2479
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9678 - loss: 0.2367 - val_accuracy: 0.9674 - val_loss: 0.2082
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9720 - loss: 0.1962 - val_accuracy: 0.9645 - val_loss: 0.1958
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9749 - loss: 0.1760 - val_accuracy: 0.9688 - val_loss: 0.1797
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9763 - loss: 0.1641 - val_accuracy: 0.9720 - val_loss: 0.1666
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9792 - loss: 0.1538 - val_accuracy: 0.9706 - val_loss: 0.1677
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9796 - loss: 0.1508 - val_accuracy: 0.9733 - val_loss: 0.1572
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9812 - loss: 0.1442 - val_accuracy: 0.9746 - val_loss: 0.1545
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7498 - loss: 2.0334 - val_accuracy: 0.9393 - val_loss: 0.7528
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9387 - loss: 0.6664 - val_accuracy: 0.9569 - val_loss: 0.4432
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9561 - loss: 0.4166 - val_accuracy: 0.9600 - val_loss: 0.3382
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9649 - loss: 0.3179 - val_accuracy: 0.9668 - val_loss: 0.2705
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9709 - loss: 0.2575 - val_accuracy: 0.9671 - val_loss: 0.2362
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9733 - loss: 0.2196 - val_accuracy: 0.9691 - val_loss: 0.2082
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9760 - loss: 0.1926 - val_accuracy: 0.9689 - val_loss: 0.1921
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9767 - loss: 0.1755 - val_accuracy: 0.9712 - val_loss: 0.1755
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9793 - loss: 0.1610 - val_accuracy: 0.9710 - val_loss: 0.1687
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9810 - loss: 0.1515 - val_accuracy: 0.9722 - val_loss: 0.1611
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7745 - loss: 1.8978 - val_accuracy: 0.9433 - val_loss: 0.7337
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9398 - loss: 0.6483 - val_accuracy: 0.9558 - val_loss: 0.4163
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9567 - loss: 0.3873 - val_accuracy: 0.9531 - val_loss: 0.3148
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9624 - loss: 0.2874 - val_accuracy: 0.9574 - val_loss: 0.2544
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9683 - loss: 0.2318 - val_accuracy: 0.9639 - val_loss: 0.2135
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9716 - loss: 0.1979 - val_accuracy: 0.9640 - val_loss: 0.1954
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9740 - loss: 0.1778 - val_accuracy: 0.9688 - val_loss: 0.1775
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9768 - loss: 0.1628 - val_accuracy: 0.9711 - val_loss: 0.1663
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9770 - loss: 0.1572 - val_accuracy: 0.9699 - val_loss: 0.1649
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9792 - loss: 0.1498 - val_accuracy: 0.9729 - val_loss: 0.1590
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
#
# Aggregated Evaluation Metrics:
# Average Accuracy: 0.9721
# Average Precision: 0.9742
# Average Recall: 0.9642
# Average F1 Score: 0.9692

# %% [markdown]
# ### Convolutional Neural network + GloVe word embeddings (100D) + 5-Fold Cross Validation + L2 regularization

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout, Concatenate, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
from sklearn.utils.class_weight import compute_class_weight

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Tokenize the already preprocessed text in 'processed_full_content' column
tokenizer = Tokenizer(num_words=5000)  # Limit to top 5000 words
tokenizer.fit_on_texts(data['processed_full_content'])
sequences = tokenizer.texts_to_sequences(data['processed_full_content'])

# Padding sequences to ensure uniform length
max_sequence_length = 300
X = pad_sequences(sequences, maxlen=max_sequence_length)
y = data['label'].values  # Labels for fake news (0 for real, 1 for fake)

# Load pre-trained GloVe embeddings
embeddings_index = {}
with open('../glove.6B.100d.txt', 'r', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# Prepare embedding matrix for the words in your dataset
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 100
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# Define CNN model with pre-trained embeddings and L2 regularization using the functional API
def create_model():
    input_layer = Input(shape=(max_sequence_length,))
    embedding_layer = Embedding(input_dim=vocab_size,
                                output_dim=embedding_dim,
                                weights=[embedding_matrix],
                                trainable=True)(input_layer)

    convs = []
    for kernel_size in [3, 4, 5]:
        conv = Conv1D(filters=64, kernel_size=kernel_size, activation='relu',
                      kernel_regularizer=l2(0.01))(embedding_layer)
        pool = GlobalMaxPooling1D()(conv)
        convs.append(pool)

    merged = Concatenate()(convs)
    dense = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(merged)
    drop = Dropout(0.5)(dense)
    output = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(drop)

    model = Model(inputs=input_layer, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Perform Stratified K-Fold Cross Validation with 5 folds
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize lists to store metrics for each fold
accuracies, precisions, recalls, f1_scores = [], [], [], []

for train_index, test_index in kfold.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Compute class weights
    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights_dict = dict(enumerate(class_weights))

    # Create and train the CNN model
    model = create_model()
    model.fit(X_train, y_train, epochs=10, batch_size=256, validation_data=(X_test, y_test),
              class_weight=class_weights_dict, verbose=1)

    # Predict and calculate metrics for this fold
    y_pred = (model.predict(X_test) > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')

    # Store metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

# Calculate average metrics across all folds
avg_accuracy = np.mean(accuracies)
avg_precision = np.mean(precisions)
avg_recall = np.mean(recalls)
avg_f1_score = np.mean(f1_scores)

# Print the classification report
print("\nAggregated Report:")
print(f"Average Accuracy: {avg_accuracy:.4f}")
print(f"Average Precision: {avg_precision:.4f}")
print(f"Average Recall: {avg_recall:.4f}")
print(f"Average F1-score: {avg_f1_score:.4f}")
# Out:
# Epoch 1/10
# 194/200 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7540 - loss: 2.5671
# 2024-11-06 14:55:22.925777: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1483', 64 bytes spill stores, 64 bytes spill loads
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7575 - loss: 2.5328 - val_accuracy: 0.9443 - val_loss: 0.5582
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9451 - loss: 0.4801 - val_accuracy: 0.9608 - val_loss: 0.2999
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9592 - loss: 0.2874 - val_accuracy: 0.9648 - val_loss: 0.2272
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9653 - loss: 0.2228 - val_accuracy: 0.9661 - val_loss: 0.2001
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9686 - loss: 0.1977 - val_accuracy: 0.9651 - val_loss: 0.1902
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9728 - loss: 0.1844 - val_accuracy: 0.9660 - val_loss: 0.1843
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9737 - loss: 0.1744 - val_accuracy: 0.9659 - val_loss: 0.1810
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9753 - loss: 0.1681 - val_accuracy: 0.9659 - val_loss: 0.1777
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9770 - loss: 0.1623 - val_accuracy: 0.9681 - val_loss: 0.1724
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9793 - loss: 0.1562 - val_accuracy: 0.9687 - val_loss: 0.1696
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7418 - loss: 2.5110 - val_accuracy: 0.9475 - val_loss: 0.5523
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9433 - loss: 0.4837 - val_accuracy: 0.9588 - val_loss: 0.3155
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9590 - loss: 0.2958 - val_accuracy: 0.9677 - val_loss: 0.2323
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9660 - loss: 0.2291 - val_accuracy: 0.9671 - val_loss: 0.2051
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9699 - loss: 0.1979 - val_accuracy: 0.9682 - val_loss: 0.1905
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9727 - loss: 0.1822 - val_accuracy: 0.9685 - val_loss: 0.1826
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9751 - loss: 0.1731 - val_accuracy: 0.9713 - val_loss: 0.1735
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9768 - loss: 0.1647 - val_accuracy: 0.9726 - val_loss: 0.1692
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9806 - loss: 0.1582 - val_accuracy: 0.9722 - val_loss: 0.1668
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9813 - loss: 0.1528 - val_accuracy: 0.9730 - val_loss: 0.1642
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7290 - loss: 2.4972 - val_accuracy: 0.9286 - val_loss: 0.5338
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9420 - loss: 0.4540 - val_accuracy: 0.9520 - val_loss: 0.3043
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9587 - loss: 0.2795 - val_accuracy: 0.9575 - val_loss: 0.2373
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9644 - loss: 0.2226 - val_accuracy: 0.9649 - val_loss: 0.1989
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9688 - loss: 0.1954 - val_accuracy: 0.9688 - val_loss: 0.1843
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9720 - loss: 0.1821 - val_accuracy: 0.9721 - val_loss: 0.1742
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9748 - loss: 0.1716 - val_accuracy: 0.9731 - val_loss: 0.1681
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9773 - loss: 0.1629 - val_accuracy: 0.9738 - val_loss: 0.1647
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9787 - loss: 0.1578 - val_accuracy: 0.9743 - val_loss: 0.1614
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9795 - loss: 0.1530 - val_accuracy: 0.9745 - val_loss: 0.1595
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 940us/step
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7442 - loss: 2.4347 - val_accuracy: 0.9447 - val_loss: 0.5200
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9447 - loss: 0.4524 - val_accuracy: 0.9619 - val_loss: 0.2869
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9587 - loss: 0.2778 - val_accuracy: 0.9650 - val_loss: 0.2224
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9648 - loss: 0.2191 - val_accuracy: 0.9675 - val_loss: 0.1975
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9681 - loss: 0.1962 - val_accuracy: 0.9680 - val_loss: 0.1868
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9714 - loss: 0.1809 - val_accuracy: 0.9687 - val_loss: 0.1809
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9741 - loss: 0.1722 - val_accuracy: 0.9689 - val_loss: 0.1775
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9766 - loss: 0.1648 - val_accuracy: 0.9691 - val_loss: 0.1734
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9787 - loss: 0.1593 - val_accuracy: 0.9699 - val_loss: 0.1712
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9803 - loss: 0.1528 - val_accuracy: 0.9700 - val_loss: 0.1696
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7482 - loss: 2.4264 - val_accuracy: 0.9374 - val_loss: 0.5009
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9425 - loss: 0.4405 - val_accuracy: 0.9547 - val_loss: 0.2920
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9574 - loss: 0.2790 - val_accuracy: 0.9558 - val_loss: 0.2349
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9643 - loss: 0.2224 - val_accuracy: 0.9615 - val_loss: 0.2050
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9675 - loss: 0.1985 - val_accuracy: 0.9658 - val_loss: 0.1873
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9706 - loss: 0.1833 - val_accuracy: 0.9674 - val_loss: 0.1793
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9723 - loss: 0.1755 - val_accuracy: 0.9692 - val_loss: 0.1730
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9746 - loss: 0.1690 - val_accuracy: 0.9700 - val_loss: 0.1693
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9778 - loss: 0.1614 - val_accuracy: 0.9702 - val_loss: 0.1669
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9787 - loss: 0.1560 - val_accuracy: 0.9708 - val_loss: 0.1648
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step
#
# Aggregated Report:
# Average Accuracy: 0.9714
# Average Precision: 0.9690
# Average Recall: 0.9682
# Average F1-score: 0.9686

# %% [markdown]
# ### Convolutional Neural network + GloVe word embeddings (300D) + 5-Fold Cross Validation + L2 regularization
#
# L2 Regularization discourages large weights by adding a penalty to the loss function. It encourages the model to find simpler solutions by minimizing both the original loss and the weight magnitudes.
#
# *Benefit*: Reduces overfitting by making the model less sensitive to noise and preventing it from memorizing specific data points.

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout, Concatenate, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
from sklearn.utils.class_weight import compute_class_weight

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Tokenize the already preprocessed text in 'processed_full_content' column
tokenizer = Tokenizer(num_words=5000)  # Limit to top 5000 words
tokenizer.fit_on_texts(data['processed_full_content'])
sequences = tokenizer.texts_to_sequences(data['processed_full_content'])

# Padding sequences to ensure uniform length
max_sequence_length = 300
X = pad_sequences(sequences, maxlen=max_sequence_length)
y = data['label'].values  # Labels for fake news (0 for real, 1 for fake)

# Load pre-trained GloVe embeddings
embeddings_index = {}
with open('../glove.6B.300d.txt', 'r', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# Prepare embedding matrix for the words in your dataset
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 300
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# Define CNN model with pre-trained embeddings and L2 regularization using the functional API
def create_model():
    input_layer = Input(shape=(max_sequence_length,))
    embedding_layer = Embedding(input_dim=vocab_size,
                                output_dim=embedding_dim,
                                weights=[embedding_matrix],
                                trainable=True)(input_layer)

    convs = []
    for kernel_size in [3, 4, 5]:
        conv = Conv1D(filters=64, kernel_size=kernel_size, activation='relu',
                      kernel_regularizer=l2(0.01))(embedding_layer)
        pool = GlobalMaxPooling1D()(conv)
        convs.append(pool)

    merged = Concatenate()(convs)
    dense = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(merged)
    drop = Dropout(0.5)(dense)
    output = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(drop)

    model = Model(inputs=input_layer, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Perform Stratified K-Fold Cross Validation with 5 folds
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize lists to store metrics for each fold
accuracies, precisions, recalls, f1_scores = [], [], [], []

for train_index, test_index in kfold.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Compute class weights
    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights_dict = dict(enumerate(class_weights))

    # Create and train the CNN model
    model = create_model()
    model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_test, y_test),
              class_weight=class_weights_dict, verbose=1)

    # Predict and calculate metrics for this fold
    y_pred = (model.predict(X_test) > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')

    # Store metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

# Calculate average metrics across all folds
avg_accuracy = np.mean(accuracies)
avg_precision = np.mean(precisions)
avg_recall = np.mean(recalls)
avg_f1_score = np.mean(f1_scores)

# Print the classification report
print("\nAggregated Report:")
print(f"Average Accuracy: {avg_accuracy:.4f}")
print(f"Average Precision: {avg_precision:.4f}")
print(f"Average Recall: {avg_recall:.4f}")
print(f"Average F1-score: {avg_f1_score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 43
#      41     embedding_vector = embeddings_index.get(word)
#      42     if embedding_vector is not None:
# ---> 43         embedding_matrix[i] = embedding_vector
#      45 # Define CNN model with pre-trained embeddings and L2 regularization using the functional API
#      46 def create_model():
#
# ValueError: could not broadcast input array from shape (300,) into shape (100,)

# %% [markdown]
# ### Convolutional Neural network + Custom-trained word2vec word embeddings + 5-Fold Cross Validation + L2 Regularization + GridSearchCV

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import make_scorer, f1_score
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from gensim.models import Word2Vec
from tensorflow.keras.regularizers import l2

# Seed for reproducibility
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# Tokenize the text
max_words = 10000  # Vocabulary size
max_sequence_length = 300  # Maximum sequence length

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(data['processed_full_content'])
sequences = tokenizer.texts_to_sequences(data['processed_full_content'])
X = pad_sequences(sequences, maxlen=max_sequence_length)
y = data['label'].values  # Labels

# Train Custom Word2Vec 
sentences = [text.split() for text in data['processed_full_content']]
embedding_dim = 100
custom_word2vec = Word2Vec(sentences, vector_size=embedding_dim, window=5, min_count=2, workers=4)

# Create Embedding Matrix
vocab_size = len(tokenizer.word_index) + 1
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in tokenizer.word_index.items():
    if i < max_words:
        if word in custom_word2vec.wv:
            embedding_matrix[i] = custom_word2vec.wv[word]
        else:
            embedding_matrix[i] = np.random.normal(size=(embedding_dim,))

# Define Model Function for KerasClassifier
def create_model(filters=128, kernel_size=5, dense_units=64, dropout_rate=0.5, l2_reg=0.01):
    input_layer = Input(shape=(max_sequence_length,))
    embedding_layer = Embedding(input_dim=vocab_size,
                                output_dim=embedding_dim,
                                weights=[embedding_matrix],
                                trainable=False)(input_layer)

    x = Conv1D(filters=filters, kernel_size=kernel_size, activation='relu', kernel_regularizer=l2(l2_reg))(embedding_layer)
    x = GlobalMaxPooling1D()(x)
    
    x = Dense(dense_units, activation='relu', kernel_regularizer=l2(l2_reg))(x)
    x = Dropout(dropout_rate)(x)
    output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_reg))(x)

    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Wrap the model with KerasClassifier
model = KerasClassifier(build_fn=create_model, verbose=1)

# Define Grid of Hyperparameters
param_grid = {
    'filters': [64, 128],
    'kernel_size': [3, 5],
    'dense_units': [32, 64],
    'dropout_rate': [0.2, 0.5],
    'l2_reg': [0.01, 0.001],
    'epochs': [5, 10],
    'batch_size': [32, 64]
}

# Define F1 Score as Scoring Metric
f1_scorer = make_scorer(f1_score, average='binary')

# Perform Grid Search
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=f1_scorer, cv=StratifiedKFold(n_splits=5), verbose=1)
grid_result = grid.fit(X, y)

# Print Best Score and Parameters
print("Best F1 Score: {:.4f}".format(grid_result.best_score_))
print("Best Parameters: ", grid_result.best_params_)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 9
#       7 from sklearn.model_selection import StratifiedKFold, GridSearchCV
#       8 from sklearn.metrics import make_scorer, f1_score
# ----> 9 from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
#      10 from gensim.models import Word2Vec
#      11 from tensorflow.keras.regularizers import l2
#
# ModuleNotFoundError: No module named 'tensorflow.keras.wrappers'
